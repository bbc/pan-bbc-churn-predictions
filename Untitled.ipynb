# %%
# Admin things
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
from time import time
import pickle
import copy

# Techy things
from sqlalchemy import create_engine
import boto3
import os
import json

# Number things
import pandas as pd
import numpy as np
import math
from scipy import interp

# Picture things
import matplotlib.pyplot as plt
import seaborn as sns
from jupyterthemes import jtplot
from IPython.display import display

# Machine learning things
from sklearn import preprocessing
from sklearn import model_selection
from sklearn import linear_model
import shap

# My things
from src import utils
from src import fi


# Directories
pickle_dir = 'pickles/iplayer'
log_dir = 'logs/iplayer'

# Plot distributions of variables? Slow on large datasets
plot_distributions = False
save_shap_sample = True

# Fetch credentials from AWS
aws_creds = utils.aws_fetch_creds()
secret_dict = utils.aws_fetch_secret('users/alex_philpotts/live/credentials')
engine_str = 'postgresql://%s:%s@localhost:5439/redshiftdb' % (
    secret_dict['redshift_username'],
    secret_dict['redshift_password'])

engine = create_engine(engine_str)

pd.options.display.max_columns = None
query = """select * from central_insights_sandbox.ap_churn_iplayer_score_sample"""
df = pd.read_sql_query(query, engine)

query = """select * from central_insights_sandbox.ap_churn_iplayer_score_sample_profiler"""
profiles = pd.read_sql_query(query, engine)

print("Data loaded\n")

# Filter to 'active last week', or relevant filter criteria for the model
df = df[df.active_last_week == 1]

## =======================
## TREATMENT
## =======================

# IMPUTING MISSING COLUMNS ==============

# Retrieving the missing value imputer
mvi = utils.unpickle(pickle_dir+'/prep/missing_value_imputer')

# Imputimg missing values on the fresh data
df_impute = mvi.score(df)

# Replacing missing value columns in fresh data with imputed columns
non_imputed = [c for c in df.columns if c not in mvi.impute_strategies.colname.values]
df = pd.concat([df[non_imputed], df_impute],  axis=1)

print("Missing value imputation completed\n")



# TRANSFORMATIONS ==============
#   --- copying the dataframe before treatment so we can average unencoded features
df_repr = copy.copy(df)

# Sqrt variables with heavily lopsided distributions
sqrt_candidates = utils.unpickle( pickle_dir+'/prep/sqrt_candidates')
df_sqrt = df[sqrt_candidates].apply(func=np.sqrt,axis=0).rename(columns=lambda x: 'sqrt_'+x)

print("Sqrt transformations completed\n")

# One-hot encoding
oh_encoder = utils.unpickle( pickle_dir+'/prep/oh_encoder')

df_OH = oh_encoder.score(df)

print("One-hot encoding completed\n")


# CONTROL ================

id_vars = utils.unpickle(pickle_dir+'/prep/id_vars')
eligibles_untreated = utils.unpickle(pickle_dir+'/prep/eligibles_untreated')
eligibles = utils.unpickle(pickle_dir+'/prep/eligibles')

# Drop deprecated / useless variables
df = pd.concat([df[id_vars + eligibles_untreated], df_sqrt, df_OH], axis=1)

target = 'target_churn_next_week'

X = df[['bbc_hid3', 'target_week_start_date']+eligibles]
X.set_index(['bbc_hid3', 'target_week_start_date'], inplace=True)
X.index.names = ['bbc_hid3', 'target_week_start_date']

# REPRESENTATIVE USERS ==============

# How we're building average users:
#  - Median of untreated / sqrted vars
#  - Mode of OH encoded vars (before OH encoding, then apply OH enconding and re-attach).
#        Tried just taking medians, but post-OH encoding this returns 0 for basically all categoricals,
#        so having to do it the long-winded way.

# Average users
median_cols = eligibles_untreated + ['sqrt_' + c for c in sqrt_candidates]
median_all = df[median_cols].median(axis=0)

# on untreated data, then applying OH encoding
mode_all = df_repr[oh_encoder.candidates].mode(axis=0)
mode_oh_all = oh_encoder.score(mode_all)

unencoded_eligibles = median_cols + oh_encoder.candidates

# 16-34 user
median_1634 = (
    df[['bbc_hid3'] + median_cols]
    .merge(profiles, how='left', on='bbc_hid3')
    .query('age_1634 == 1')
    .filter(items = median_cols)
    .median(axis=0)
)

mode_1634 = (
    df_repr[['bbc_hid3']+oh_encoder.candidates]
    .merge(profiles, how='left', on='bbc_hid3')
    .query('age_1634 == 1')
    .filter(items=oh_encoder.candidates)
    .mode(axis=0)
)
mode_oh_1634 = oh_encoder.score(mode_1634)

average_users = pd.DataFrame({
    'base': median_all.append(mode_oh_all.iloc[0,]),
    'u35': median_1634.append(mode_oh_1634.iloc[0,])
}, index=eligibles)
average_df = average_users.T
average_df.index.names = ['group']

average_users.to_csv(log_dir+'/average_users.csv')
# Out:
# AWS access key ID:  ASIAZSDWL7RXPR67M67O
# AWS secret access key:  wiP0jR5YMhBD8lH9uwXvpL/s7iROXfJPAhDqgggh
# AWS default region:  eu-west-1
# AWS session token:  
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-149-a94bb82a969c> in <module>
#      46 # Fetch credentials from AWS
#      47 aws_creds = utils.aws_fetch_creds()
# ---> 48 secret_dict = utils.aws_fetch_secret('users/alex_philpotts/live/credentials')
#      49 engine_str = 'postgresql://%s:%s@localhost:5439/redshiftdb' % (
#      50     secret_dict['redshift_username'],
#
# ~/Documents/Repos/pan-bbc-churn/src/utils.py in aws_fetch_secret(secret_name)
#      75
#      76     # Get Secrets from AWS
# ---> 77     secret = client.get_secret_value(SecretId=secret_name)
#      78     secret_dict = json.loads(secret['SecretString'])
#      79
#
# ~/anaconda3/envs/churn/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/churn/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     659             error_code = parsed_response.get("Error", {}).get("Code")
#     660             error_class = self.exceptions.from_code(error_code)
# --> 661             raise error_class(parsed_response, operation_name)
#     662         else:
#     663             return parsed_response
#
# ClientError: An error occurred (ExpiredTokenException) when calling the GetSecretValue operation: The security token included in the request is expired

# %%
# BUILD MODIFIED USERS ==============

# Read modifications from csv
modifiers  = pd.read_csv('data/modifiers_average_user.csv', index_col=0)
base_user = pd.DataFrame({
    'user_id': 'base',
    'feature': unencoded_eligibles,
    'baseval': median_all.append(mode_all.iloc[0,])
},
index=unencoded_eligibles
)
base_user.to_csv(log_dir+'/base_test.csv')
# Nudge or replace values depending on method column
modifiers['mod_column'] = modifiers.index

# Cross join the base onto all modifiers (we want one modification per row)
base_user['mergekey'] = 0
modifiers['mergekey'] = 0
modified_all = modifiers.merge(base_user, on='mergekey', how='inner')
base_user.drop('mergekey', axis=1, inplace=True)
modifiers.drop('mergekey', axis=1, inplace=True)


modified_all['newval'] = modified_all['baseval']

modified_all.set_index(['user_id'], inplace=True)
delta_rows = (modified_all['method'] == 'delta') & (modified_all['feature'] == modified_all['mod_column'])
modified_all.loc[delta_rows, 'newval'] = modified_all.loc[delta_rows, 'baseval'] + \
    modified_all.loc[delta_rows, 'modifier'].astype(float)

replace_rows = (modified_all['method'] == 'replace') & (modified_all['feature'] == modified_all['mod_column'])
modified_all.loc[replace_rows, 'newval'] = modified_all.loc[replace_rows, 'modifier']
modified_all.drop(['mergekey','method','modifier','baseval'], axis=1, inplace=True)

modified_all = modified_all.set_index(['mod_column', 'feature'], append=True).unstack('feature')

modified_all.columns = modified_all.columns.droplevel()

# Converting base user into same format so we can stack it on
base_user['mod_column'] = 'none'
base_user = base_user.reset_index().set_index(['user_id', 'mod_column', 'index']).drop('feature', axis=1).unstack()
base_user.columns = base_user.columns.droplevel()

# modified_all = pd.concat([base_user, modified_all], axis=0)
def tidy_encode(df, num_vars, encoder):
    "Handling the encoding of categorical variables and converting numericals to floats"
    treated_df = pd.concat(
        [df[num_vars].astype(float),
         encoder.score(df[encoder.candidates])
        ],
    axis=1
    )
    return treated_df

base_user = tidy_encode(base_user, eligibles_untreated, oh_encoder)
modified_users = tidy_encode(modified_all, eligibles_untreated, oh_encoder)
# Out:
#                                             profile_enablepersonalisation  \
# user_id mod_column
# base    freq_seg_latest_news                                          1.0
#         freq_seg_latest_sounds                                        1.0
#         freq_seg_latest_sport                                         1.0
#         genre_distinct_count                                          1.0
#         genre_share_childrens                                         1.0
#         genre_share_drama                                             1.0
#         iplayer_fav_content_genre                                     1.0
#         iplayer_fav_content_masterbrand                               1.0
#         iplayer_programme_follows_13w                                 1.0
#         iplayer_programme_follows_lastweek                            1.0
#         lw_distinct_episodes                                          1.0
#         lw_distinct_series                                            1.0
#         lw_series_finales                                             1.0
#         lw_series_premieres                                           1.0
#
#                                             profile_mailverified  \
# user_id mod_column
# base    freq_seg_latest_news                                 0.0
#         freq_seg_latest_sounds                               0.0
#         freq_seg_latest_sport                                0.0
#         genre_distinct_count                                 0.0
#         genre_share_childrens                                0.0
#         genre_share_drama                                    0.0
#         iplayer_fav_content_genre                            0.0
#         iplayer_fav_content_masterbrand                      0.0
#         iplayer_programme_follows_13w                        0.0
#         iplayer_programme_follows_lastweek                   0.0
#         lw_distinct_episodes                                 0.0
#         lw_distinct_series                                   0.0
#         lw_series_finales                                    0.0
#         lw_series_premieres                                  0.0
#
#                                             profile_acc_age_days  \
# user_id mod_column
# base    freq_seg_latest_news                               876.0
#         freq_seg_latest_sounds                             876.0
#         freq_seg_latest_sport                              876.0
#         genre_distinct_count                               876.0
#         genre_share_childrens                              876.0
#         genre_share_drama                                  876.0
#         iplayer_fav_content_genre                          876.0
#         iplayer_fav_content_masterbrand                    876.0
#         iplayer_programme_follows_13w                      876.0
#         iplayer_programme_follows_lastweek                 876.0
#         lw_distinct_episodes                               876.0
#         lw_distinct_series                                 876.0
#         lw_series_finales                                  876.0
#         lw_series_premieres                                876.0
#
#                                             profile_age_1634_enriched  \
# user_id mod_column
# base    freq_seg_latest_news                                      0.0
#         freq_seg_latest_sounds                                    0.0
#         freq_seg_latest_sport                                     0.0
#         genre_distinct_count                                      0.0
#         genre_share_childrens                                     0.0
#         genre_share_drama                                         0.0
#         iplayer_fav_content_genre                                 0.0
#         iplayer_fav_content_masterbrand                           0.0
#         iplayer_programme_follows_13w                             0.0
#         iplayer_programme_follows_lastweek                        0.0
#         lw_distinct_episodes                                      0.0
#         lw_distinct_series                                        0.0
#         lw_series_finales                                         0.0
#         lw_series_premieres                                       0.0
#
#                                             streaming_time_13w   stw_2  \
# user_id mod_column
# base    freq_seg_latest_news                           63068.5  5255.5
#         freq_seg_latest_sounds                         63068.5  5255.5
#         freq_seg_latest_sport                          63068.5  5255.5
#         genre_distinct_count                           63068.5  5255.5
#         genre_share_childrens                          63068.5  5255.5
#         genre_share_drama                              63068.5  5255.5
#         iplayer_fav_content_genre                      63068.5  5255.5
#         iplayer_fav_content_masterbrand                63068.5  5255.5
#         iplayer_programme_follows_13w                  63068.5  5255.5
#         iplayer_programme_follows_lastweek             63068.5  5255.5
#         lw_distinct_episodes                           63068.5  5255.5
#         lw_distinct_series                             63068.5  5255.5
#         lw_series_finales                              63068.5  5255.5
#         lw_series_premieres                            63068.5  5255.5
#
#                                              stw_3   stw_4   stw_5   stw_6  \
# user_id mod_column
# base    freq_seg_latest_news                3438.0  2999.0  2849.0  2288.0
#         freq_seg_latest_sounds              3438.0  2999.0  2849.0  2288.0
#         freq_seg_latest_sport               3438.0  2999.0  2849.0  2288.0
#         genre_distinct_count                3438.0  2999.0  2849.0  2288.0
#         genre_share_childrens               3438.0  2999.0  2849.0  2288.0
#         genre_share_drama                   3438.0  2999.0  2849.0  2288.0
#         iplayer_fav_content_genre           3438.0  2999.0  2849.0  2288.0
#         iplayer_fav_content_masterbrand     3438.0  2999.0  2849.0  2288.0
#         iplayer_programme_follows_13w       3438.0  2999.0  2849.0  2288.0
#         iplayer_programme_follows_lastweek  3438.0  2999.0  2849.0  2288.0
#         lw_distinct_episodes                3438.0  2999.0  2849.0  2288.0
#         lw_distinct_series                  3438.0  2999.0  2849.0  2288.0
#         lw_series_finales                   3438.0  2999.0  2849.0  2288.0
#         lw_series_premieres                 3438.0  2999.0  2849.0  2288.0
#
#                                              stw_7   stw_8   stw_9  stw_10  \
# user_id mod_column
# base    freq_seg_latest_news                2520.0  2722.5  3453.0  2834.0
#         freq_seg_latest_sounds              2520.0  2722.5  3453.0  2834.0
#         freq_seg_latest_sport               2520.0  2722.5  3453.0  2834.0
#         genre_distinct_count                2520.0  2722.5  3453.0  2834.0
#         genre_share_childrens               2520.0  2722.5  3453.0  2834.0
#         genre_share_drama                   2520.0  2722.5  3453.0  2834.0
#         iplayer_fav_content_genre           2520.0  2722.5  3453.0  2834.0
#         iplayer_fav_content_masterbrand     2520.0  2722.5  3453.0  2834.0
#         iplayer_programme_follows_13w       2520.0  2722.5  3453.0  2834.0
#         iplayer_programme_follows_lastweek  2520.0  2722.5  3453.0  2834.0
#         lw_distinct_episodes                2520.0  2722.5  3453.0  2834.0
#         lw_distinct_series                  2520.0  2722.5  3453.0  2834.0
#         lw_series_finales                   2520.0  2722.5  3453.0  2834.0
#         lw_series_premieres                 2520.0  2722.5  3453.0  2834.0
#
#                                             stw_11  stw_12  stw_13  stw_14  \
# user_id mod_column
# base    freq_seg_latest_news                1618.0  1872.0  1761.0  1757.5
#         freq_seg_latest_sounds              1618.0  1872.0  1761.0  1757.5
#         freq_seg_latest_sport               1618.0  1872.0  1761.0  1757.5
#         genre_distinct_count                1618.0  1872.0  1761.0  1757.5
#         genre_share_childrens               1618.0  1872.0  1761.0  1757.5
#         genre_share_drama                   1618.0  1872.0  1761.0  1757.5
#         iplayer_fav_content_genre           1618.0  1872.0  1761.0  1757.5
#         iplayer_fav_content_masterbrand     1618.0  1872.0  1761.0  1757.5
#         iplayer_programme_follows_13w       1618.0  1872.0  1761.0  1757.5
#         iplayer_programme_follows_lastweek  1618.0  1872.0  1761.0  1757.5
#         lw_distinct_episodes                1618.0  1872.0  1761.0  1757.5
#         lw_distinct_series                  1618.0  1872.0  1761.0  1757.5
#         lw_series_finales                   1618.0  1872.0  1761.0  1757.5
#         lw_series_premieres                 1618.0  1872.0  1761.0  1757.5
#
#                                             ew_2  ew_3  ew_4  ew_5  ew_6  \
# user_id mod_column
# base    freq_seg_latest_news                21.0  15.0  14.0  13.0  11.0
#         freq_seg_latest_sounds              21.0  15.0  14.0  13.0  11.0
#         freq_seg_latest_sport               21.0  15.0  14.0  13.0  11.0
#         genre_distinct_count                21.0  15.0  14.0  13.0  11.0
#         genre_share_childrens               21.0  15.0  14.0  13.0  11.0
#         genre_share_drama                   21.0  15.0  14.0  13.0  11.0
#         iplayer_fav_content_genre           21.0  15.0  14.0  13.0  11.0
#         iplayer_fav_content_masterbrand     21.0  15.0  14.0  13.0  11.0
#         iplayer_programme_follows_13w       21.0  15.0  14.0  13.0  11.0
#         iplayer_programme_follows_lastweek  21.0  15.0  14.0  13.0  11.0
#         lw_distinct_episodes                21.0  15.0  14.0  13.0  11.0
#         lw_distinct_series                  21.0  15.0  14.0  13.0  11.0
#         lw_series_finales                   21.0  15.0  14.0  13.0  11.0
#         lw_series_premieres                 21.0  15.0  14.0  13.0  11.0
#
#                                             ew_7  ew_8  ew_9  ew_10  ew_11  \
# user_id mod_column
# base    freq_seg_latest_news                12.0  13.0  14.0   12.0   10.0
#         freq_seg_latest_sounds              12.0  13.0  14.0   12.0   10.0
#         freq_seg_latest_sport               12.0  13.0  14.0   12.0   10.0
#         genre_distinct_count                12.0  13.0  14.0   12.0   10.0
#         genre_share_childrens               12.0  13.0  14.0   12.0   10.0
#         genre_share_drama                   12.0  13.0  14.0   12.0   10.0
#         iplayer_fav_content_genre           12.0  13.0  14.0   12.0   10.0
#         iplayer_fav_content_masterbrand     12.0  13.0  14.0   12.0   10.0
#         iplayer_programme_follows_13w       12.0  13.0  14.0   12.0   10.0
#         iplayer_programme_follows_lastweek  12.0  13.0  14.0   12.0   10.0
#         lw_distinct_episodes                12.0  13.0  14.0   12.0   10.0
#         lw_distinct_series                  12.0  13.0  14.0   12.0   10.0
#         lw_series_finales                   12.0  13.0  14.0   12.0   10.0
#         lw_series_premieres                 12.0  13.0  14.0   12.0   10.0
#
#                                             ew_12  ew_13  ew_14  \
# user_id mod_column
# base    freq_seg_latest_news                 11.0   10.0   10.0
#         freq_seg_latest_sounds               11.0   10.0   10.0
#         freq_seg_latest_sport                11.0   10.0   10.0
#         genre_distinct_count                 11.0   10.0   10.0
#         genre_share_childrens                11.0   10.0   10.0
#         genre_share_drama                    11.0   10.0   10.0
#         iplayer_fav_content_genre            11.0   10.0   10.0
#         iplayer_fav_content_masterbrand      11.0   10.0   10.0
#         iplayer_programme_follows_13w        11.0   10.0   10.0
#         iplayer_programme_follows_lastweek   11.0   10.0   10.0
#         lw_distinct_episodes                 11.0   10.0   10.0
#         lw_distinct_series                   11.0   10.0   10.0
#         lw_series_finales                    11.0   10.0   10.0
#         lw_series_premieres                  11.0   10.0   10.0
#
#                                             iplayer_lin_reg_coeff  \
# user_id mod_column
# base    freq_seg_latest_news                            -0.346154
#         freq_seg_latest_sounds                          -0.346154
#         freq_seg_latest_sport                           -0.346154
#         genre_distinct_count                            -0.346154
#         genre_share_childrens                           -0.346154
#         genre_share_drama                               -0.346154
#         iplayer_fav_content_genre                       -0.346154
#         iplayer_fav_content_masterbrand                 -0.346154
#         iplayer_programme_follows_13w                   -0.346154
#         iplayer_programme_follows_lastweek              -0.346154
#         lw_distinct_episodes                            -0.346154
#         lw_distinct_series                              -0.346154
#         lw_series_finales                               -0.346154
#         lw_series_premieres                             -0.346154
#
#                                             iplayer_13w_yintercept  \
# user_id mod_column
# base    freq_seg_latest_news                             18.884615
#         freq_seg_latest_sounds                           18.884615
#         freq_seg_latest_sport                            18.884615
#         genre_distinct_count                             18.884615
#         genre_share_childrens                            18.884615
#         genre_share_drama                                18.884615
#         iplayer_fav_content_genre                        18.884615
#         iplayer_fav_content_masterbrand                  18.884615
#         iplayer_programme_follows_13w                    18.884615
#         iplayer_programme_follows_lastweek               18.884615
#         lw_distinct_episodes                             18.884615
#         lw_distinct_series                               18.884615
#         lw_series_finales                                18.884615
#         lw_series_premieres                              18.884615
#
#                                             iplayer_13w_xintercept  \
# user_id mod_column
# base    freq_seg_latest_news                             17.101266
#         freq_seg_latest_sounds                           17.101266
#         freq_seg_latest_sport                            17.101266
#         genre_distinct_count                             17.101266
#         genre_share_childrens                            17.101266
#         genre_share_drama                                17.101266
#         iplayer_fav_content_genre                        17.101266
#         iplayer_fav_content_masterbrand                  17.101266
#         iplayer_programme_follows_13w                    17.101266
#         iplayer_programme_follows_lastweek               17.101266
#         lw_distinct_episodes                             17.101266
#         lw_distinct_series                               17.101266
#         lw_series_finales                                17.101266
#         lw_series_premieres                              17.101266
#
#                                             iplayer_lin_reg_churn_flag  \
# user_id mod_column
# base    freq_seg_latest_news                                       1.0
#         freq_seg_latest_sounds                                     1.0
#         freq_seg_latest_sport                                      1.0
#         genre_distinct_count                                       1.0
#         genre_share_childrens                                      1.0
#         genre_share_drama                                          1.0
#         iplayer_fav_content_genre                                  1.0
#         iplayer_fav_content_masterbrand                            1.0
#         iplayer_programme_follows_13w                              1.0
#         iplayer_programme_follows_lastweek                         1.0
#         lw_distinct_episodes                                       1.0
#         lw_distinct_series                                         1.0
#         lw_series_finales                                          1.0
#         lw_series_premieres                                        1.0
#
#                                             sounds_user  \
# user_id mod_column
# base    freq_seg_latest_news                        0.0
#         freq_seg_latest_sounds                      0.0
#         freq_seg_latest_sport                       0.0
#         genre_distinct_count                        0.0
#         genre_share_childrens                       0.0
#         genre_share_drama                           0.0
#         iplayer_fav_content_genre                   0.0
#         iplayer_fav_content_masterbrand             0.0
#         iplayer_programme_follows_13w               0.0
#         iplayer_programme_follows_lastweek          0.0
#         lw_distinct_episodes                        0.0
#         lw_distinct_series                          0.0
#         lw_series_finales                           0.0
#         lw_series_premieres                         0.0
#
#                                             sounds_active_last_week  \
# user_id mod_column
# base    freq_seg_latest_news                                    0.0
#         freq_seg_latest_sounds                                  0.0
#         freq_seg_latest_sport                                   0.0
#         genre_distinct_count                                    0.0
#         genre_share_childrens                                   0.0
#         genre_share_drama                                       0.0
#         iplayer_fav_content_genre                               0.0
#         iplayer_fav_content_masterbrand                         0.0
#         iplayer_programme_follows_13w                           0.0
#         iplayer_programme_follows_lastweek                      0.0
#         lw_distinct_episodes                                    0.0
#         lw_distinct_series                                      0.0
#         lw_series_finales                                       0.0
#         lw_series_premieres                                     0.0
#
#                                             sounds_lin_reg_coeff  \
# user_id mod_column
# base    freq_seg_latest_news                                 0.0
#         freq_seg_latest_sounds                               0.0
#         freq_seg_latest_sport                                0.0
#         genre_distinct_count                                 0.0
#         genre_share_childrens                                0.0
#         genre_share_drama                                    0.0
#         iplayer_fav_content_genre                            0.0
#         iplayer_fav_content_masterbrand                      0.0
#         iplayer_programme_follows_13w                        0.0
#         iplayer_programme_follows_lastweek                   0.0
#         lw_distinct_episodes                                 0.0
#         lw_distinct_series                                   0.0
#         lw_series_finales                                    0.0
#         lw_series_premieres                                  0.0
#
#                                             sounds_13w_yintercept  \
# user_id mod_column
# base    freq_seg_latest_news                             0.807692
#         freq_seg_latest_sounds                           0.807692
#         freq_seg_latest_sport                            0.807692
#         genre_distinct_count                             0.807692
#         genre_share_childrens                            0.807692
#         genre_share_drama                                0.807692
#         iplayer_fav_content_genre                        0.807692
#         iplayer_fav_content_masterbrand                  0.807692
#         iplayer_programme_follows_13w                    0.807692
#         iplayer_programme_follows_lastweek               0.807692
#         lw_distinct_episodes                             0.807692
#         lw_distinct_series                               0.807692
#         lw_series_finales                                0.807692
#         lw_series_premieres                              0.807692
#
#                                             sounds_13w_xintercept  \
# user_id mod_column
# base    freq_seg_latest_news                                 14.0
#         freq_seg_latest_sounds                               14.0
#         freq_seg_latest_sport                                14.0
#         genre_distinct_count                                 14.0
#         genre_share_childrens                                14.0
#         genre_share_drama                                    14.0
#         iplayer_fav_content_genre                            14.0
#         iplayer_fav_content_masterbrand                      14.0
#         iplayer_programme_follows_13w                        14.0
#         iplayer_programme_follows_lastweek                   14.0
#         lw_distinct_episodes                                 14.0
#         lw_distinct_series                                   14.0
#         lw_series_finales                                    14.0
#         lw_series_premieres                                  14.0
#
#                                             sounds_lin_reg_churn_flag  \
# user_id mod_column
# base    freq_seg_latest_news                                      0.0
#         freq_seg_latest_sounds                                    0.0
#         freq_seg_latest_sport                                     0.0
#         genre_distinct_count                                      0.0
#         genre_share_childrens                                     0.0
#         genre_share_drama                                         0.0
#         iplayer_fav_content_genre                                 0.0
#         iplayer_fav_content_masterbrand                           0.0
#         iplayer_programme_follows_13w                             0.0
#         iplayer_programme_follows_lastweek                        0.0
#         lw_distinct_episodes                                      0.0
#         lw_distinct_series                                        0.0
#         lw_series_finales                                         0.0
#         lw_series_premieres                                       0.0
#
#                                             genre_share_comedy  \
# user_id mod_column
# base    freq_seg_latest_news                          0.024075
#         freq_seg_latest_sounds                        0.024075
#         freq_seg_latest_sport                         0.024075
#         genre_distinct_count                          0.024075
#         genre_share_childrens                         0.024075
#         genre_share_drama                             0.024075
#         iplayer_fav_content_genre                     0.024075
#         iplayer_fav_content_masterbrand               0.024075
#         iplayer_programme_follows_13w                 0.024075
#         iplayer_programme_follows_lastweek            0.024075
#         lw_distinct_episodes                          0.024075
#         lw_distinct_series                            0.024075
#         lw_series_finales                             0.024075
#         lw_series_premieres                           0.024075
#
#                                             genre_share_drama  \
# user_id mod_column
# base    freq_seg_latest_news                         0.350202
#         freq_seg_latest_sounds                       0.350202
#         freq_seg_latest_sport                        0.350202
#         genre_distinct_count                         0.350202
#         genre_share_childrens                        0.350202
#         genre_share_drama                            0.650202
#         iplayer_fav_content_genre                    0.350202
#         iplayer_fav_content_masterbrand              0.350202
#         iplayer_programme_follows_13w                0.350202
#         iplayer_programme_follows_lastweek           0.350202
#         lw_distinct_episodes                         0.350202
#         lw_distinct_series                           0.350202
#         lw_series_finales                            0.350202
#         lw_series_premieres                          0.350202
#
#                                             genre_share_ents  \
# user_id mod_column
# base    freq_seg_latest_news                             0.0
#         freq_seg_latest_sounds                           0.0
#         freq_seg_latest_sport                            0.0
#         genre_distinct_count                             0.0
#         genre_share_childrens                            0.0
#         genre_share_drama                                0.0
#         iplayer_fav_content_genre                        0.0
#         iplayer_fav_content_masterbrand                  0.0
#         iplayer_programme_follows_13w                    0.0
#         iplayer_programme_follows_lastweek               0.0
#         lw_distinct_episodes                             0.0
#         lw_distinct_series                               0.0
#         lw_series_finales                                0.0
#         lw_series_premieres                              0.0
#
#                                             genre_share_childrens  \
# user_id mod_column
# base    freq_seg_latest_news                                  0.0
#         freq_seg_latest_sounds                                0.0
#         freq_seg_latest_sport                                 0.0
#         genre_distinct_count                                  0.0
#         genre_share_childrens                                 0.3
#         genre_share_drama                                     0.0
#         iplayer_fav_content_genre                             0.0
#         iplayer_fav_content_masterbrand                       0.0
#         iplayer_programme_follows_13w                         0.0
#         iplayer_programme_follows_lastweek                    0.0
#         lw_distinct_episodes                                  0.0
#         lw_distinct_series                                    0.0
#         lw_series_finales                                     0.0
#         lw_series_premieres                                   0.0
#
#                                             genre_share_factual  \
# user_id mod_column
# base    freq_seg_latest_news                            0.13838
#         freq_seg_latest_sounds                          0.13838
#         freq_seg_latest_sport                           0.13838
#         genre_distinct_count                            0.13838
#         genre_share_childrens                           0.13838
#         genre_share_drama                               0.13838
#         iplayer_fav_content_genre                       0.13838
#         iplayer_fav_content_masterbrand                 0.13838
#         iplayer_programme_follows_13w                   0.13838
#         iplayer_programme_follows_lastweek              0.13838
#         lw_distinct_episodes                            0.13838
#         lw_distinct_series                              0.13838
#         lw_series_finales                               0.13838
#         lw_series_premieres                             0.13838
#
#                                             genre_share_learning  \
# user_id mod_column
# base    freq_seg_latest_news                                 0.0
#         freq_seg_latest_sounds                               0.0
#         freq_seg_latest_sport                                0.0
#         genre_distinct_count                                 0.0
#         genre_share_childrens                                0.0
#         genre_share_drama                                    0.0
#         iplayer_fav_content_genre                            0.0
#         iplayer_fav_content_masterbrand                      0.0
#         iplayer_programme_follows_13w                        0.0
#         iplayer_programme_follows_lastweek                   0.0
#         lw_distinct_episodes                                 0.0
#         lw_distinct_series                                   0.0
#         lw_series_finales                                    0.0
#         lw_series_premieres                                  0.0
#
#                                             genre_share_music  \
# user_id mod_column
# base    freq_seg_latest_news                              0.0
#         freq_seg_latest_sounds                            0.0
#         freq_seg_latest_sport                             0.0
#         genre_distinct_count                              0.0
#         genre_share_childrens                             0.0
#         genre_share_drama                                 0.0
#         iplayer_fav_content_genre                         0.0
#         iplayer_fav_content_masterbrand                   0.0
#         iplayer_programme_follows_13w                     0.0
#         iplayer_programme_follows_lastweek                0.0
#         lw_distinct_episodes                              0.0
#         lw_distinct_series                                0.0
#         lw_series_finales                                 0.0
#         lw_series_premieres                               0.0
#
#                                             genre_share_news  \
# user_id mod_column
# base    freq_seg_latest_news                             0.0
#         freq_seg_latest_sounds                           0.0
#         freq_seg_latest_sport                            0.0
#         genre_distinct_count                             0.0
#         genre_share_childrens                            0.0
#         genre_share_drama                                0.0
#         iplayer_fav_content_genre                        0.0
#         iplayer_fav_content_masterbrand                  0.0
#         iplayer_programme_follows_13w                    0.0
#         iplayer_programme_follows_lastweek               0.0
#         lw_distinct_episodes                             0.0
#         lw_distinct_series                               0.0
#         lw_series_finales                                0.0
#         lw_series_premieres                              0.0
#
#                                             genre_share_religion  \
# user_id mod_column
# base    freq_seg_latest_news                                 0.0
#         freq_seg_latest_sounds                               0.0
#         freq_seg_latest_sport                                0.0
#         genre_distinct_count                                 0.0
#         genre_share_childrens                                0.0
#         genre_share_drama                                    0.0
#         iplayer_fav_content_genre                            0.0
#         iplayer_fav_content_masterbrand                      0.0
#         iplayer_programme_follows_13w                        0.0
#         iplayer_programme_follows_lastweek                   0.0
#         lw_distinct_episodes                                 0.0
#         lw_distinct_series                                   0.0
#         lw_series_finales                                    0.0
#         lw_series_premieres                                  0.0
#
#                                             genre_share_sport  \
# user_id mod_column
# base    freq_seg_latest_news                              0.0
#         freq_seg_latest_sounds                            0.0
#         freq_seg_latest_sport                             0.0
#         genre_distinct_count                              0.0
#         genre_share_childrens                             0.0
#         genre_share_drama                                 0.0
#         iplayer_fav_content_genre                         0.0
#         iplayer_fav_content_masterbrand                   0.0
#         iplayer_programme_follows_13w                     0.0
#         iplayer_programme_follows_lastweek                0.0
#         lw_distinct_episodes                              0.0
#         lw_distinct_series                                0.0
#         lw_series_finales                                 0.0
#         lw_series_premieres                               0.0
#
#                                             genre_share_weather  \
# user_id mod_column
# base    freq_seg_latest_news                                0.0
#         freq_seg_latest_sounds                              0.0
#         freq_seg_latest_sport                               0.0
#         genre_distinct_count                                0.0
#         genre_share_childrens                               0.0
#         genre_share_drama                                   0.0
#         iplayer_fav_content_genre                           0.0
#         iplayer_fav_content_masterbrand                     0.0
#         iplayer_programme_follows_13w                       0.0
#         iplayer_programme_follows_lastweek                  0.0
#         lw_distinct_episodes                                0.0
#         lw_distinct_series                                  0.0
#         lw_series_finales                                   0.0
#         lw_series_premieres                                 0.0
#
#                                             genre_distinct_count  \
# user_id mod_column
# base    freq_seg_latest_news                                 5.0
#         freq_seg_latest_sounds                               5.0
#         freq_seg_latest_sport                                5.0
#         genre_distinct_count                                 6.0
#         genre_share_childrens                                5.0
#         genre_share_drama                                    5.0
#         iplayer_fav_content_genre                            5.0
#         iplayer_fav_content_masterbrand                      5.0
#         iplayer_programme_follows_13w                        5.0
#         iplayer_programme_follows_lastweek                   5.0
#         lw_distinct_episodes                                 5.0
#         lw_distinct_series                                   5.0
#         lw_series_finales                                    5.0
#         lw_series_premieres                                  5.0
#
#                                             releases_comedies  \
# user_id mod_column
# base    freq_seg_latest_news                              8.0
#         freq_seg_latest_sounds                            8.0
#         freq_seg_latest_sport                             8.0
#         genre_distinct_count                              8.0
#         genre_share_childrens                             8.0
#         genre_share_drama                                 8.0
#         iplayer_fav_content_genre                         8.0
#         iplayer_fav_content_masterbrand                   8.0
#         iplayer_programme_follows_13w                     8.0
#         iplayer_programme_follows_lastweek                8.0
#         lw_distinct_episodes                              8.0
#         lw_distinct_series                                8.0
#         lw_series_finales                                 8.0
#         lw_series_premieres                               8.0
#
#                                             releases_dramas  releases_ents  \
# user_id mod_column
# base    freq_seg_latest_news                           16.0           14.0
#         freq_seg_latest_sounds                         16.0           14.0
#         freq_seg_latest_sport                          16.0           14.0
#         genre_distinct_count                           16.0           14.0
#         genre_share_childrens                          16.0           14.0
#         genre_share_drama                              16.0           14.0
#         iplayer_fav_content_genre                      16.0           14.0
#         iplayer_fav_content_masterbrand                16.0           14.0
#         iplayer_programme_follows_13w                  16.0           14.0
#         iplayer_programme_follows_lastweek             16.0           14.0
#         lw_distinct_episodes                           16.0           14.0
#         lw_distinct_series                             16.0           14.0
#         lw_series_finales                              16.0           14.0
#         lw_series_premieres                            16.0           14.0
#
#                                             releases_childrens  \
# user_id mod_column
# base    freq_seg_latest_news                              55.0
#         freq_seg_latest_sounds                            55.0
#         freq_seg_latest_sport                             55.0
#         genre_distinct_count                              55.0
#         genre_share_childrens                             55.0
#         genre_share_drama                                 55.0
#         iplayer_fav_content_genre                         55.0
#         iplayer_fav_content_masterbrand                   55.0
#         iplayer_programme_follows_13w                     55.0
#         iplayer_programme_follows_lastweek                55.0
#         lw_distinct_episodes                              55.0
#         lw_distinct_series                                55.0
#         lw_series_finales                                 55.0
#         lw_series_premieres                               55.0
#
#                                             releases_factual  \
# user_id mod_column
# base    freq_seg_latest_news                           190.0
#         freq_seg_latest_sounds                         190.0
#         freq_seg_latest_sport                          190.0
#         genre_distinct_count                           190.0
#         genre_share_childrens                          190.0
#         genre_share_drama                              190.0
#         iplayer_fav_content_genre                      190.0
#         iplayer_fav_content_masterbrand                190.0
#         iplayer_programme_follows_13w                  190.0
#         iplayer_programme_follows_lastweek             190.0
#         lw_distinct_episodes                           190.0
#         lw_distinct_series                             190.0
#         lw_series_finales                              190.0
#         lw_series_premieres                            190.0
#
#                                             releases_learning  releases_music  \
# user_id mod_column
# base    freq_seg_latest_news                              2.0            36.0
#         freq_seg_latest_sounds                            2.0            36.0
#         freq_seg_latest_sport                             2.0            36.0
#         genre_distinct_count                              2.0            36.0
#         genre_share_childrens                             2.0            36.0
#         genre_share_drama                                 2.0            36.0
#         iplayer_fav_content_genre                         2.0            36.0
#         iplayer_fav_content_masterbrand                   2.0            36.0
#         iplayer_programme_follows_13w                     2.0            36.0
#         iplayer_programme_follows_lastweek                2.0            36.0
#         lw_distinct_episodes                              2.0            36.0
#         lw_distinct_series                                2.0            36.0
#         lw_series_finales                                 2.0            36.0
#         lw_series_premieres                               2.0            36.0
#
#                                             releases_news  releases_religion  \
# user_id mod_column
# base    freq_seg_latest_news                         89.0                2.0
#         freq_seg_latest_sounds                       89.0                2.0
#         freq_seg_latest_sport                        89.0                2.0
#         genre_distinct_count                         89.0                2.0
#         genre_share_childrens                        89.0                2.0
#         genre_share_drama                            89.0                2.0
#         iplayer_fav_content_genre                    89.0                2.0
#         iplayer_fav_content_masterbrand              89.0                2.0
#         iplayer_programme_follows_13w                89.0                2.0
#         iplayer_programme_follows_lastweek           89.0                2.0
#         lw_distinct_episodes                         89.0                2.0
#         lw_distinct_series                           89.0                2.0
#         lw_series_finales                            89.0                2.0
#         lw_series_premieres                          89.0                2.0
#
#                                             releases_sport  \
# user_id mod_column
# base    freq_seg_latest_news                          45.0
#         freq_seg_latest_sounds                        45.0
#         freq_seg_latest_sport                         45.0
#         genre_distinct_count                          45.0
#         genre_share_childrens                         45.0
#         genre_share_drama                             45.0
#         iplayer_fav_content_genre                     45.0
#         iplayer_fav_content_masterbrand               45.0
#         iplayer_programme_follows_13w                 45.0
#         iplayer_programme_follows_lastweek            45.0
#         lw_distinct_episodes                          45.0
#         lw_distinct_series                            45.0
#         lw_series_finales                             45.0
#         lw_series_premieres                           45.0
#
#                                             scaled_releases_comedies  \
# user_id mod_column
# base    freq_seg_latest_news                                0.781955
#         freq_seg_latest_sounds                              0.781955
#         freq_seg_latest_sport                               0.781955
#         genre_distinct_count                                0.781955
#         genre_share_childrens                               0.781955
#         genre_share_drama                                   0.781955
#         iplayer_fav_content_genre                           0.781955
#         iplayer_fav_content_masterbrand                     0.781955
#         iplayer_programme_follows_13w                       0.781955
#         iplayer_programme_follows_lastweek                  0.781955
#         lw_distinct_episodes                                0.781955
#         lw_distinct_series                                  0.781955
#         lw_series_finales                                   0.781955
#         lw_series_premieres                                 0.781955
#
#                                             scaled_releases_dramas  \
# user_id mod_column
# base    freq_seg_latest_news                              0.967442
#         freq_seg_latest_sounds                            0.967442
#         freq_seg_latest_sport                             0.967442
#         genre_distinct_count                              0.967442
#         genre_share_childrens                             0.967442
#         genre_share_drama                                 0.967442
#         iplayer_fav_content_genre                         0.967442
#         iplayer_fav_content_masterbrand                   0.967442
#         iplayer_programme_follows_13w                     0.967442
#         iplayer_programme_follows_lastweek                0.967442
#         lw_distinct_episodes                              0.967442
#         lw_distinct_series                                0.967442
#         lw_series_finales                                 0.967442
#         lw_series_premieres                               0.967442
#
#                                             scaled_releases_ents  \
# user_id mod_column
# base    freq_seg_latest_news                            1.144654
#         freq_seg_latest_sounds                          1.144654
#         freq_seg_latest_sport                           1.144654
#         genre_distinct_count                            1.144654
#         genre_share_childrens                           1.144654
#         genre_share_drama                               1.144654
#         iplayer_fav_content_genre                       1.144654
#         iplayer_fav_content_masterbrand                 1.144654
#         iplayer_programme_follows_13w                   1.144654
#         iplayer_programme_follows_lastweek              1.144654
#         lw_distinct_episodes                            1.144654
# ...
#         freq_seg_latest_sport                                                   0
#         genre_distinct_count                                                    0
#         genre_share_childrens                                                   0
#         genre_share_drama                                                       0
#         iplayer_fav_content_genre                                               0
#         iplayer_fav_content_masterbrand                                         0
#         iplayer_programme_follows_13w                                           0
#         iplayer_programme_follows_lastweek                                      0
#         lw_distinct_episodes                                                    0
#         lw_distinct_series                                                      0
#         lw_series_finales                                                       0
#         lw_series_premieres                                                     0
#
#                                             device_iplayer_st_preferred_smart-tv  \
# user_id mod_column
# base    freq_seg_latest_news                                                   1
#         freq_seg_latest_sounds                                                 1
#         freq_seg_latest_sport                                                  1
#         genre_distinct_count                                                   1
#         genre_share_childrens                                                  1
#         genre_share_drama                                                      1
#         iplayer_fav_content_genre                                              1
#         iplayer_fav_content_masterbrand                                        1
#         iplayer_programme_follows_13w                                          1
#         iplayer_programme_follows_lastweek                                     1
#         lw_distinct_episodes                                                   1
#         lw_distinct_series                                                     1
#         lw_series_finales                                                      1
#         lw_series_premieres                                                    1
#
#                                             device_sounds_ev_preferred_desktop-web  \
# user_id mod_column
# base    freq_seg_latest_news                                                     1
#         freq_seg_latest_sounds                                                   1
#         freq_seg_latest_sport                                                    1
#         genre_distinct_count                                                     1
#         genre_share_childrens                                                    1
#         genre_share_drama                                                        1
#         iplayer_fav_content_genre                                                1
#         iplayer_fav_content_masterbrand                                          1
#         iplayer_programme_follows_13w                                            1
#         iplayer_programme_follows_lastweek                                       1
#         lw_distinct_episodes                                                     1
#         lw_distinct_series                                                       1
#         lw_series_finales                                                        1
#         lw_series_premieres                                                      1
#
#                                             device_sounds_ev_preferred_mobile-app  \
# user_id mod_column
# base    freq_seg_latest_news                                                    0
#         freq_seg_latest_sounds                                                  0
#         freq_seg_latest_sport                                                   0
#         genre_distinct_count                                                    0
#         genre_share_childrens                                                   0
#         genre_share_drama                                                       0
#         iplayer_fav_content_genre                                               0
#         iplayer_fav_content_masterbrand                                         0
#         iplayer_programme_follows_13w                                           0
#         iplayer_programme_follows_lastweek                                      0
#         lw_distinct_episodes                                                    0
#         lw_distinct_series                                                      0
#         lw_series_finales                                                       0
#         lw_series_premieres                                                     0
#
#                                             device_sounds_ev_preferred_mobile-web  \
# user_id mod_column
# base    freq_seg_latest_news                                                    0
#         freq_seg_latest_sounds                                                  0
#         freq_seg_latest_sport                                                   0
#         genre_distinct_count                                                    0
#         genre_share_childrens                                                   0
#         genre_share_drama                                                       0
#         iplayer_fav_content_genre                                               0
#         iplayer_fav_content_masterbrand                                         0
#         iplayer_programme_follows_13w                                           0
#         iplayer_programme_follows_lastweek                                      0
#         lw_distinct_episodes                                                    0
#         lw_distinct_series                                                      0
#         lw_series_finales                                                       0
#         lw_series_premieres                                                     0
#
#                                             device_sounds_ev_preferred_other-web  \
# user_id mod_column
# base    freq_seg_latest_news                                                   0
#         freq_seg_latest_sounds                                                 0
#         freq_seg_latest_sport                                                  0
#         genre_distinct_count                                                   0
#         genre_share_childrens                                                  0
#         genre_share_drama                                                      0
#         iplayer_fav_content_genre                                              0
#         iplayer_fav_content_masterbrand                                        0
#         iplayer_programme_follows_13w                                          0
#         iplayer_programme_follows_lastweek                                     0
#         lw_distinct_episodes                                                   0
#         lw_distinct_series                                                     0
#         lw_series_finales                                                      0
#         lw_series_premieres                                                    0
#
#                                             device_sounds_ev_preferred_smart-tv  \
# user_id mod_column
# base    freq_seg_latest_news                                                  0
#         freq_seg_latest_sounds                                                0
#         freq_seg_latest_sport                                                 0
#         genre_distinct_count                                                  0
#         genre_share_childrens                                                 0
#         genre_share_drama                                                     0
#         iplayer_fav_content_genre                                             0
#         iplayer_fav_content_masterbrand                                       0
#         iplayer_programme_follows_13w                                         0
#         iplayer_programme_follows_lastweek                                    0
#         lw_distinct_episodes                                                  0
#         lw_distinct_series                                                    0
#         lw_series_finales                                                     0
#         lw_series_premieres                                                   0
#
#                                             device_iplayer_ev_preferred_desktop-web  \
# user_id mod_column
# base    freq_seg_latest_news                                                      0
#         freq_seg_latest_sounds                                                    0
#         freq_seg_latest_sport                                                     0
#         genre_distinct_count                                                      0
#         genre_share_childrens                                                     0
#         genre_share_drama                                                         0
#         iplayer_fav_content_genre                                                 0
#         iplayer_fav_content_masterbrand                                           0
#         iplayer_programme_follows_13w                                             0
#         iplayer_programme_follows_lastweek                                        0
#         lw_distinct_episodes                                                      0
#         lw_distinct_series                                                        0
#         lw_series_finales                                                         0
#         lw_series_premieres                                                       0
#
#                                             device_iplayer_ev_preferred_mobile-app  \
# user_id mod_column
# base    freq_seg_latest_news                                                     0
#         freq_seg_latest_sounds                                                   0
#         freq_seg_latest_sport                                                    0
#         genre_distinct_count                                                     0
#         genre_share_childrens                                                    0
#         genre_share_drama                                                        0
#         iplayer_fav_content_genre                                                0
#         iplayer_fav_content_masterbrand                                          0
#         iplayer_programme_follows_13w                                            0
#         iplayer_programme_follows_lastweek                                       0
#         lw_distinct_episodes                                                     0
#         lw_distinct_series                                                       0
#         lw_series_finales                                                        0
#         lw_series_premieres                                                      0
#
#                                             device_iplayer_ev_preferred_mobile-web  \
# user_id mod_column
# base    freq_seg_latest_news                                                     0
#         freq_seg_latest_sounds                                                   0
#         freq_seg_latest_sport                                                    0
#         genre_distinct_count                                                     0
#         genre_share_childrens                                                    0
#         genre_share_drama                                                        0
#         iplayer_fav_content_genre                                                0
#         iplayer_fav_content_masterbrand                                          0
#         iplayer_programme_follows_13w                                            0
#         iplayer_programme_follows_lastweek                                       0
#         lw_distinct_episodes                                                     0
#         lw_distinct_series                                                       0
#         lw_series_finales                                                        0
#         lw_series_premieres                                                      0
#
#                                             device_iplayer_ev_preferred_other-web  \
# user_id mod_column
# base    freq_seg_latest_news                                                    0
#         freq_seg_latest_sounds                                                  0
#         freq_seg_latest_sport                                                   0
#         genre_distinct_count                                                    0
#         genre_share_childrens                                                   0
#         genre_share_drama                                                       0
#         iplayer_fav_content_genre                                               0
#         iplayer_fav_content_masterbrand                                         0
#         iplayer_programme_follows_13w                                           0
#         iplayer_programme_follows_lastweek                                      0
#         lw_distinct_episodes                                                    0
#         lw_distinct_series                                                      0
#         lw_series_finales                                                       0
#         lw_series_premieres                                                     0
#
#                                             device_iplayer_ev_preferred_smart-tv
# user_id mod_column
# base    freq_seg_latest_news                                                   1
#         freq_seg_latest_sounds                                                 1
#         freq_seg_latest_sport                                                  1
#         genre_distinct_count                                                   1
#         genre_share_childrens                                                  1
#         genre_share_drama                                                      1
#         iplayer_fav_content_genre                                              1
#         iplayer_fav_content_masterbrand                                        1
#         iplayer_programme_follows_13w                                          1
#         iplayer_programme_follows_lastweek                                     1
#         lw_distinct_episodes                                                   1
#         lw_distinct_series                                                     1
#         lw_series_finales                                                      1
#         lw_series_premieres                                                    1

# %%
# print('\nModified:\n')
# modified_users

stack = utils.unpickle(pickle_dir+'/models/stack')

# REPRESENTATIVE USERS
base_prediction = stack.predict(base_user, save_weak_learner_predictions = True, save_shap_sample = save_shap_sample)
modified_predictions = stack.predict(modified_users, save_weak_learner_predictions = True, save_shap_sample = save_shap_sample)

# Build dataset of base values, modifications and predictions
pd.DataFrame({
    'base_prediction': base_prediction[0],
    'modified_prediction': modified_predictions
}, index=modified_users.index)

# modified_all[eligibles_untreated]
# oh_encoder.score(modified_all[oh_encoder.candidates])
# Out:
# 0 MODEL:  Content :
#
#
#
# 1 MODEL:  Behaviour :
#
#
#
# 2 MODEL:  Marketing :
#
#
#
# 3 MODEL:  Cross-Sell :
#
#
#
# =======
# Stacking.
#
# Complete!
#
# 0 MODEL:  Content :
#
#
#
# 1 MODEL:  Behaviour :
#
#
#
# 2 MODEL:  Marketing :
#
#
#
# 3 MODEL:  Cross-Sell :
#
#
#
# =======
# Stacking.
#
# Complete!
#                                             base_prediction  \
# user_id mod_column
# base    freq_seg_latest_news                       0.170733
#         freq_seg_latest_sounds                     0.170733
#         freq_seg_latest_sport                      0.170733
#         genre_distinct_count                       0.170733
#         genre_share_childrens                      0.170733
#         genre_share_drama                          0.170733
#         iplayer_fav_content_genre                  0.170733
#         iplayer_fav_content_masterbrand            0.170733
#         iplayer_programme_follows_13w              0.170733
#         iplayer_programme_follows_lastweek         0.170733
#         lw_distinct_episodes                       0.170733
#         lw_distinct_series                         0.170733
#         lw_series_finales                          0.170733
#         lw_series_premieres                        0.170733
#
#                                             modified_prediction
# user_id mod_column
# base    freq_seg_latest_news                           0.172008
#         freq_seg_latest_sounds                         0.175178
#         freq_seg_latest_sport                          0.172200
#         genre_distinct_count                           0.145938
#         genre_share_childrens                          0.162289
#         genre_share_drama                              0.158540
#         iplayer_fav_content_genre                      0.170733
#         iplayer_fav_content_masterbrand                0.170733
#         iplayer_programme_follows_13w                  0.170733
#         iplayer_programme_follows_lastweek             0.170733
#         lw_distinct_episodes                           0.141543
#         lw_distinct_series                             0.155259
#         lw_series_finales                              0.222187
#         lw_series_premieres                            0.212878

# %%
modifiers
# Out:
#                                                        modifier   method  \
# lw_distinct_series                                            1    delta
# lw_distinct_episodes                                          1    delta
# lw_series_premieres                                           1    delta
# lw_series_finales                                             1    delta
# iplayer_programme_follows_13w                                10    delta
# iplayer_programme_follows_lastweek                            1    delta
# genre_distinct_count                                          1    delta
# genre_share_childrens                                       0.3    delta
# genre_share_drama                                           0.3    delta
# iplayer_fav_content_masterbrand                       BBC Three  replace
# iplayer_fav_content_genre                                 Drama  replace
# freq_seg_latest_sounds              A. daily (5+ days per week)  replace
# freq_seg_latest_news                       B. 2-5 days per week  replace
# freq_seg_latest_sport                                E. monthly  replace
#
#                                                             mod_column
# lw_distinct_series                                  lw_distinct_series
# lw_distinct_episodes                              lw_distinct_episodes
# lw_series_premieres                                lw_series_premieres
# lw_series_finales                                    lw_series_finales
# iplayer_programme_follows_13w            iplayer_programme_follows_13w
# iplayer_programme_follows_lastweek  iplayer_programme_follows_lastweek
# genre_distinct_count                              genre_distinct_count
# genre_share_childrens                            genre_share_childrens
# genre_share_drama                                    genre_share_drama
# iplayer_fav_content_masterbrand        iplayer_fav_content_masterbrand
# iplayer_fav_content_genre                    iplayer_fav_content_genre
# freq_seg_latest_sounds                          freq_seg_latest_sounds
# freq_seg_latest_news                              freq_seg_latest_news
# freq_seg_latest_sport                            freq_seg_latest_sport

# %%
# MODEL SCORING ==============

stack = utils.unpickle(pickle_dir+'/models/stack')

# REPRESENTATIVE USERS
repr_predictions = stack.predict(average_df, save_weak_learner_predictions = True, save_shap_sample = save_shap_sample)

repr_weak_learner_preds_wide = stack.weak_learner_predictions
repr_weak_learner_preds_long = pd.melt(
    repr_weak_learner_preds_wide.reset_index(), id_vars = 'group', var_name = 'weak_learner', value_name='prediction'
)
repr_weak_learner_classes_wide = stack.weak_learner_classifications
repr_weak_learner_classes_long = pd.melt(
    repr_weak_learner_classes_wide.reset_index(), id_vars = 'group', var_name = 'weak_learner', value_name='classification'
)

# Retrieving class threshold from the stack dictionary
repr_weak_learner_thresholds = pd.DataFrame(stack.weak_learner_thresholds.items(), columns = ['weak_learner', 'threshold'])
repr_weak_learner_classes_long = repr_weak_learner_classes_long.merge(repr_weak_learner_thresholds, left_on='weak_learner', right_on='weak_learner')

print(repr_weak_learner_preds_long.head(10))
print(repr_weak_learner_classes_long.head(10))

# PUSH SCORES TO REDSHIFT ==============
from datetime import datetime

# Export meta-model scores to Redshift
df_export_meta = pd.DataFrame({
    'representative_user': average_df.index,
    'learner_type': 'meta-learner',
    'learner_name': 'iplayer-meta',
    'predicted_probability': repr_predictions
})
print(df_export_meta.head())

df_export_weak = pd.DataFrame({
    'representative_user': repr_weak_learner_preds_long['group'],
    'learner_type': 'weak-learner',
    'learner_name': repr_weak_learner_preds_long['weak_learner'],
    'predicted_probability': repr_weak_learner_preds_long['prediction']
})
print(df_export_weak.head())

df_export = pd.concat([df_export_meta, df_export_weak])

df_export['score_datetime'] = datetime.today().strftime('%Y-%m-%d %H:%M:%S')


utils.rs_upload(df=df_export,
                s3_obj='s3://central-insights/philpa03/loyalty-propensity-scores/model-scores-reps',
                tmp='./data/model-scores-reps.csv',
                rs_table='central_insights_sandbox.ap_churn_iplayer_representative_user_scores',
                aws_creds=aws_creds, # to access AWS
                secret_dict=secret_dict, # to access Redshift
                truncate=True,
                csv=True,
                gzip=False
                )


# Export SHAP data to s3

# print(stack.shap_sample_dict['little_lgbm'].head(10))
if save_shap_sample:
    for (model_name, shap_values) in stack.shap_sample_dict.items():
    
        ### Update the archive with scores for this date - WILL OVERWRITE IF THE DATA ISN'T UPDATED
        shap_values.reset_index(level=['group'], inplace=True)
    
        # Add whole batch to the representatives folder in s3
        (shap_values
            .drop(['group'], axis=1)
            .to_csv('s3://central-insights/philpa03/loyalty/iplayer/shap-values/representatives/{model}.csv'.format(model = model_name), index=True)
            )

# Export feature importances to S3
for (model_name, fi) in stack.fi_dict.items():

    # Average the feature importance across folds and push to S3
    (pd.DataFrame(fi.importances.mean(1), columns=['gain'])
        .rename_axis('feature')
        .to_csv('s3://central-insights/philpa03/loyalty/iplayer/fi/representatives/{model}.csv'.format(model = model_name), index=True)
    )
